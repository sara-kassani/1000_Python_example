# %%
import math, numpy
import scipy.misc
from scipy.misc.pilutil import Image
# opening the image and converting it to grayscale
a = Image.open('data/angiogram1.jpg').convert('L')
# a is converted to an ndarray
a
# Out:
# <PIL.Image.Image image mode=L size=640x360 at 0x7FBEEE22E5C0>

# %%
b = scipy.misc.fromimage(a)
b
# Out:
# array([[154, 154, 155, ..., 154, 158, 156],
#        [152, 154, 154, ..., 155, 158, 156],
#        [156, 157, 156, ..., 156, 158, 155],
#        ...,
#        [157, 155, 153, ..., 160, 159, 159],
#        [154, 154, 154, ..., 159, 159, 158],
#        [154, 155, 157, ..., 158, 158, 158]], dtype=uint8)

# %%
# gamma is initialized
gamma = 0.5
# b is converted to type float
b1 = b.astype(float)
# maximum value in b1 is determined
b3 = numpy.max(b1)
# b1 is normalized
b2 = b1/b3
# gamma-correction exponent is computed
b3 = numpy.log(b2)*gamma
# gamma-correction is performed
c = numpy.exp(b3)*255.0
# c is converted to type int
c1 = c.astype(int)
# c1 is converted from ndarray to image
d = scipy.misc.toimage(c1)
# displaying the image
d
# Out:
# /home/sara/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log
#   # Remove the CWD from sys.path while we load stuff.
# <PIL.Image.Image image mode=L size=640x360 at 0x7FBEEE2392B0>

# %%
d.show()
