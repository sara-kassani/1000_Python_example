# %%
import scipy.misc
import scipy.ndimage
from scipy.misc.pilutil import Image
# opening the image and converting it to grayscale
a = Image.open('data/flower/tiger.png').convert('L')
a
# Out:
# <PIL.Image.Image image mode=L size=384x256 at 0x7F95CADA8550>

# %%
# performing the median filter
b = scipy.ndimage.filters.median_filter(a,size=5, footprint=None,output=None,mode='reflect', cval=0.0,origin=0)
# b is converted from an ndarray to an image
b = scipy.misc.toimage(b)
b.save('data/flower/median_output.png')
b
# Out:
# <PIL.Image.Image image mode=L size=384x256 at 0x7F95F3C64908>

# %%
# performing the median filter
b = scipy.ndimage.filters.median_filter(a,size=3, footprint=None,output=None,mode='reflect', cval=0.0,origin=0)
# b is converted from an ndarray to an image
b = scipy.misc.toimage(b)
b
# Out:
# <PIL.Image.Image image mode=L size=384x256 at 0x7F95F3C64828>

# %%
# performing the median filter
b = scipy.ndimage.filters.median_filter(a,size=4, footprint=None,output=None,mode='wrap', cval=0.0,origin=0)
# b is converted from an ndarray to an image
b = scipy.misc.toimage(b)
b
# Out:
# <PIL.Image.Image image mode=L size=384x256 at 0x7F95F3C05978>

# %%
a = Image.open('data/flower/helena.png').convert('L')
a
# Out:
# <PIL.Image.Image image mode=L size=514x537 at 0x7F95F3C05278>

# %%
# performing the median filter
b = scipy.ndimage.filters.median_filter(a,size=4, footprint=None,output=None,mode='wrap', cval=0.0,origin=0)
# b is converted from an ndarray to an image
b = scipy.misc.toimage(b)
b
# Out:
# <PIL.Image.Image image mode=L size=514x537 at 0x7F95F3C05BA8>
