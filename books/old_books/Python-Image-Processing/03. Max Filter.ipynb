# %%
import scipy.ndimage
from scipy.misc.pilutil import Image
# opening the image and converting it to grayscale
a = Image.open('data/flower/black-flower1.png').convert('L')
a
# Out:
# <PIL.Image.Image image mode=L size=500x336 at 0x7FB37F58AA90>

# %%
# performing maximum filter
b = scipy.ndimage.filters.maximum_filter(a,size=5, footprint=None,output=None,mode='reflect', cval=0.0,origin=0)
# b is converted from an ndarray to an image
b
# Out:
# array([[ 94,  95,  95, ..., 213, 213, 213],
#        [ 94,  95,  95, ..., 213, 213, 213],
#        [ 94,  95,  95, ..., 213, 213, 213],
#        ...,
#        [  9,   9,   9, ..., 121, 121, 121],
#        [  9,   9,   9, ..., 119, 119, 119],
#        [  9,   9,   9, ..., 115, 115, 115]], dtype=uint8)

# %%
b = scipy.misc.toimage(b)
b.save('data/flower/max-filter.png')

# %%
b
# Out:
# <PIL.Image.Image image mode=L size=500x336 at 0x7FB3A0C36E48>

# %%
# opening the image and converting it to grayscale
a = Image.open('data/flower/flower2.jpeg').convert('L')
a
# Out:
# <PIL.Image.Image image mode=L size=314x161 at 0x7FB3A8480A20>

# %%
# performing maximum filter
b = scipy.ndimage.filters.maximum_filter(a,size=4, footprint=None,output=None,mode='wrap', cval=0.0,origin=0)
# b is converted from an ndarray to an image
b = scipy.misc.toimage(b)
b
# Out:
# <PIL.Image.Image image mode=L size=314x161 at 0x7FB3A8480DA0>
