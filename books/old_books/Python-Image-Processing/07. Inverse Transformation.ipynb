# %%
import math
import scipy.misc
import numpy as np
from scipy.misc.pilutil import Image
# opening the image and converting it to grayscale
im = Image.open('data/heart.jpg').convert('L')
im
# Out:
# <PIL.Image.Image image mode=L size=511x445 at 0x7FBEEF247400>

# %%
# im is converted to an ndarray
im1 = scipy.misc.fromimage(im)
# performing the inversion operation
im2 = 255 - im1
# im2 is converted from an ndarray to an image
im3 = scipy.misc.toimage(im2)
# saving the image as imageinverse_output.png in
# Figures folder
#im3.save('../Figures/imageinverse_output.png')
im3
# Out:
# <PIL.Image.Image image mode=L size=511x445 at 0x7FBEEF2472E8>

# %%
import math
import scipy.misc
import numpy as np
from scipy.misc.pilutil import Image
# opening the image and converting it to grayscale
im = Image.open('data/heart1.jpeg').convert('L')
im
# Out:
# <PIL.Image.Image image mode=L size=248x203 at 0x7FBEEF247240>

# %%
# im is converted to an ndarray
im1 = scipy.misc.fromimage(im)
# performing the inversion operation
im2 = 255 - im1
# im2 is converted from an ndarray to an image
im3 = scipy.misc.toimage(im2)
# saving the image as imageinverse_output.png in
# Figures folder
#im3.save('../Figures/imageinverse_output.png')
im3
# Out:
# <PIL.Image.Image image mode=L size=248x203 at 0x7FBEEF251BA8>
